# %%
link="https://raw.githubusercontent.com/AshishJangra27/Machine-Learning-with-Python-GFG/main/Regression/1%20Linear%20Regression/data_for_lr.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(link)

# %%
data.head(5)
# Out:
#       x          y
# 0  24.0  21.549452
# 1  50.0  47.464463
# 2  15.0  17.218656
# 3  38.0  36.586398
# 4  87.0  87.288984

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB

# %%
data=data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 699 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       699 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 16.4 KB

# %%
data.shape
# Out:
# (699, 2)

# %%
# training data
train_input=np.array(data["x"][0:500]).reshape(500,1)
train_output=np.array(data["y"][0:500]).reshape(500,1)

# testing data
test_input=np.array(data["x"][500:700]).reshape(199,1)
test_output=np.array(data["y"][500:700]).reshape(199,1)

# %%
# forward propogation

def forward_propagation(train_input,parameters):
    m=parameters['m']
    c=parameters['c']
    predictions=np.multiply(m,train_input)+c
    return predictions

# cost function (mean squared error)

def cost_function(predictions,train_output):
    cost=np.mean((train_output-predictions)**2)/2
    return cost

# backward_propagation(gradient descent)

def backward_propagation(train_input,train_output,predictions):
    derivatives=dict()
    df=predictions-train_output
    dm=np.mean(np.multiply(train_input,df))
    dc=np.mean(df)
    derivatives['dm']=dm
    derivatives['dc']=dc
    return derivatives

# updating parameters

def update_parameters(parameters,derivatives,learning_rate):
    parameters['m']-=(learning_rate*derivatives['dm'])
    parameters['c']-=(learning_rate*derivatives['dc'])
    return parameters

# %%
# training data

def train(train_input,train_output,learning_rate,iters):
    parameters=dict()
    parameters['m']=np.random.uniform(0,1)
    parameters['c']=np.random.uniform(0,1)
    print(f'Initial parameters : {parameters}')
    
    loss=list()
    
    for i in range(iters):
        
        #forward_propagation
        predictions=forward_propagation(train_input,parameters)
        
        #cost function
        cost=cost_function(predictions,train_input)
        
        loss.append(cost)
        print(f"Iteration : {i+1} ,Cost : {cost}")
        
        plt.plot(train_input,train_output,'+')
        plt.plot(train_input,predictions,'*')
        plt.show()
        #backward propagation
        derivatives=backward_propagation(train_input,train_output,predictions)
        
        #update parameters
        parameters=update_parameters(parameters,derivatives,learning_rate)
    
    return parameters,loss

# %%
learning_rate=0.0001
iters=20
parameters,loss=train(train_input,train_output,learning_rate,iters)
print(f'Final parameters : {parameters}')
# Out:
# Initial parameters : {'m': 0.7668433128747917, 'c': 0.8400843621027044}
# Iteration : 1 ,Cost : 79.38061984238422
# Iteration : 2 ,Cost : 36.47240784787048
# Iteration : 3 ,Cost : 16.87352173879429
# Iteration : 4 ,Cost : 7.892988414964446
# Iteration : 5 ,Cost : 3.758900253267096
# Iteration : 6 ,Cost : 1.843106970553532
# Iteration : 7 ,Cost : 0.9468624785142767
# Iteration : 8 ,Cost : 0.5220162192706966
# Iteration : 9 ,Cost : 0.3169900431582285
# Iteration : 10 ,Cost : 0.2157016727722929
# Iteration : 11 ,Cost : 0.16417704955739262
# Iteration : 12 ,Cost : 0.13704745303224586
# Iteration : 13 ,Cost : 0.12220989746047203
# Iteration : 14 ,Cost : 0.11377370185120794
# Iteration : 15 ,Cost : 0.10879713621168222
# Iteration : 16 ,Cost : 0.10576426130387762
# Iteration : 17 ,Cost : 0.10386519309261917
# Iteration : 18 ,Cost : 0.10265024249603891
# Iteration : 19 ,Cost : 0.10185998784597589
# Iteration : 20 ,Cost : 0.10133941514196051
# Final parameters : {'m': 0.9845832857525725, 'c': 0.8428374827598818}

# %%
plt.plot(loss)

# %%
# testing data

# %%
test_predictions=test_input*parameters['m']+parameters['c']
plt.plot(test_input,test_output,'+')
plt.plot(test_input,test_predictions,'.')
plt.show()

# %%
# cost for test data

cost=cost_function(test_predictions,test_output)
print(cost)
# Out:
# 4.041942096470173
